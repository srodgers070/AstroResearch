# %% [markdown]
# # KUGEG Radio Galaxy Database Walkthrough
# ### Produced by: Spencer Rodgers sarodgers070@ku.edu
# The first thing required to use the database is to make sure that you have access to the files! If you do not have them you can get them from my github repository that contains all the relevant documentation:

# %% [markdown]
# #### Now that you have the files we import the class I have written. The first thing you must ALWAYS do when using a database is connect to it. This is done with the following statement:
# <br>
# cur=ConnectDB(database)
# <br>

# %% [markdown]
# #### Make sure the database statement is formatted as a string. We can try this out with the example I have included. Run the line below to see this

# %%
import DataBase as db
cur=db.connect("Committed.db")
db.TableChecker(cur)
# db.AddReducedData(cur, "H11")
# db.AddReducedData(cur, "H6")
# db.AddReducedData(cur, "G9")
db.AddReducedData(cur, "D4")
# Out:
# The tables present are:
#
# ('H11_ReducedDataBoard1',)
# ('H11_ReducedDataBoard2',)
# ('H6_ReducedDataBoard1',)
# ('H6_ReducedDataBoard2',)
# ('G9_ReducedDataBoard1',)
# ('G9_ReducedDataBoard2',)
# Loading data for D4 Board 1...
# D4/Board1ReducedData.txt
# Data successfully loaded!
#
# Loading data for D4 Board 2...
# D4/Board2ReducedData.txt
# Data successfully loaded!
#
# Connected to database, will now upload data to specified table...
# Board 1 has been added to database, moving to board 2...
#
# Board 2 has been added to database.
# AddReducedData is complete, closing connection to database

# %%
# db.TableChecker(cur)
data=db.GrabReducedData(cur, "D4","1")
# print(data)

db.PlotFrequencies(data[:,0],data[:,2], "D4 Board1")
# Out:
# Connected to database, will now grab data...
# data loaded...

# %% [markdown]
# #### To enable interactive plotting simply run the line below. This will allow you to examine regions that you are interested in with ease and save images so that you can .
